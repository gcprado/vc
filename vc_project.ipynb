# %% [markdown]
# <a href="https://colab.research.google.com/github/gcprado/vc/blob/main/vc_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Jan  6 08:56:57 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# Train the model
results = model.train(data="SKU-110K.yaml", epochs=10, imgsz=640, batch=8)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.248 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r yolov8_train_results.zip /content/runs/detect/train/
# Out:
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/BoxR_curve.png (deflated 17%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 6%)
#   adding: content/runs/detect/train/BoxPR_curve.png (deflated 20%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 5%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 3%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 2%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 3%)
#   adding: content/runs/detect/train/val_batch1_labels.jpg (deflated 2%)
#   adding: content/runs/detect/train/BoxP_curve.png (deflated 20%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 3%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 6%)
#   adding: content/runs/detect/train/BoxF1_curve.png (deflated 17%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 32%)
# ...
